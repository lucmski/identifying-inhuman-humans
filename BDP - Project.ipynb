# %%
import tweepy
import csv
import pprint
import json

# %%
# sagar's keys
# consumer_key = 'KlIvRIuDPRq6NQTdFPXpVh96v'
# consumer_secret = 'I92dpWQo89ULGCNmpGtwo01t5fVRvWyhPPJyXRTr3cN6KBwtCV'
# access_token = '866792900-KS0Y8s2nl4haGSyGax2E1PPAGoxejfCeSh18weU8'
# access_token_secret = 'SgtPu7DH7mCjbbXVETSSdGt07o8IBdkEJHI55sQKHdavT'

# kshitij's keys
consumer_key = "yyeI5zSWvvLVGSol7hu0tJ9gE"
consumer_secret = "3N4fjsuLTCV4tIXEMICf587lM6mC7i8kcF4Ju1FSnx6VdKKLaW"
access_token = "187109182-3vx120Tp28CEDfKZXB3JaZd5SV04DIZkhuIPEWfG"
access_token_secret = "OXA5aGEXXqibb1FKl31EyVdLVVBqZnDrzS22oLy6KzCuh"

auth = tweepy.auth.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
results_no_retweets = []
try:
    for status in tweepy.Cursor(api.search, q = "#ISIS -filter:retweets", tweet_mode = 'extended').items():
        results_no_retweets.append(status._json)
except :
    print('error')
# Out:
# error

# %%
# results = [status._json for status in tweepy.Cursor(api.search, q="#ISIS", count = 2000, tweet_mode='extended').items()]
# latest  ID (#ISIS)- 1112665440571015168
# latest ID (#AlQaeda) - 1109085045304844290
# latest ID (#alQaida) - 1104080012578304001
results = []
try:
    for status in tweepy.Cursor(api.search, q = "#ISIS", tweet_mode = 'extended', since_id = 1112642900733714432).items():
        results.append(status._json)
except :
    print('error')

# %%
pprint.pprint(results[1]['retweeted_status']['entities']['hashtags'][0]['text'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-390-e1ca89db0010> in <module>()
# ----> 1 pprint.pprint(results[1]['retweeted_status']['entities']['hashtags'][0]['text'])
#
# KeyError: 'retweeted_status'

# %%
results = []
with open('./alqaeda_tweets.json', 'r') as f:
    for item in f:
        results.append(json.loads(item))

# %%
with open('new_isis_tweets.csv', 'a') as f:
    header = 'DateTime,Location,Geo Tag,Tweet ID,Language,Hashtags,User Mentions,Retweet Count,Tweet Favorite Count,Device,User Id,User Name,Screen Name,Active Since,Tweet Count,Verification Status,Followers Count,Following Count,URL,Full Tweet, Terror Group'
    f.write(header)
    f.write('\n')

# %%
with open('new_isis_tweets.csv', 'a') as f:
    for tweet in results:
        if 'retweeted_status' in tweet.keys():
            
            tweet_attr = tweet['retweeted_status']
            user_attr = tweet['retweeted_status']['user']
            entities_attr = tweet['retweeted_status']['entities']
            
            date_time = tweet_attr['created_at']
            location = tweet_attr['user']['location'].replace(',', ' ')
            if len(location) == 0:
                location = 'None'
            geo = tweet_attr['geo']
            if geo is None:
                geo = 'None'
            else:
                geo = str(geo['coordinates'][0]) + str(geo['coordinates'][1])
            tweet_id = tweet_attr['id_str']
            lang = tweet_attr['lang']
            if len(entities_attr['hashtags']) == 0:
                hashtags = 'None'
            else:
                hashtags_list = []
                for hashtag in entities_attr['hashtags']:
                    hashtags_list.append('#' + hashtag['text'])
                hashtags = " ".join(hashtags_list)
            if len(entities_attr['user_mentions']) == 0:
                user_mentions = 'None'
            else:
                user_mentions_list = []
                for user in entities_attr['user_mentions']:
                    user_mentions_list.append('@' + user['screen_name'])
                user_mentions = ' '.join(user_mentions_list)
            retweet_count = str(tweet_attr['retweet_count'])
            favorite_count = str(tweet_attr['favorite_count'])
            device = tweet_attr['source']
            if 'Android' in device:
                device = 'Android'
            elif 'Iphone' in device:
                device = 'Iphone'
            elif 'Web Client' in device:
                device = 'Twitter Web Client'
            elif 'Paper' in device:
                device = 'Paper.ii'
            elif 'Tweet Deck' in device:
                device = 'Tweet Deck'
            else:
                device = 'Other'
            user_id = user_attr['id_str']
            user_name = user_attr['name'].replace(',', ' ')
            screen_name = user_attr['screen_name'].replace(',', ' ')
            joining_data = user_attr['created_at']
            tweet_count = str(user_attr['statuses_count'])
            verified = str(user_attr['verified'])
            followers = str(user_attr['followers_count'])
            following = str(user_attr['friends_count'])
            url = user_attr['url']
            if url is None:
                url = 'None'
            text = tweet_attr['full_text'].replace('\n', ' ').replace(',', ' ').replace(';', ' ')
            group = 'ISIS'
            
            row = date_time + ',' + location + ',' + geo + ',' + tweet_id + ',' + lang + ',' + hashtags \
            + ',' + user_mentions + ',' + retweet_count + ',' + favorite_count \
            + ',' + device + ',' + user_id + ',' + user_name + ',' + screen_name \
            + ',' + joining_data + ',' + tweet_count + ',' + verified + ',' + followers \
            + ',' + following + ',' + url + ',' + text + ',' + group + '\n'
            
            f.write(row)
        
        else:
            
            tweet_attr = tweet
            user_attr = tweet_attr['user']
            entities_attr = tweet['entities']
            
            date_time = tweet_attr['created_at']
            location = tweet_attr['user']['location'].replace(',', ' ')
            if len(location) == 0:
                location = 'None'
            geo = tweet_attr['geo']
            if geo is None:
                geo = 'None'
            else:
                geo = str(geo['coordinates'][0]) + str(geo['coordinates'][1])
            tweet_id = tweet_attr['id_str']
            lang = tweet_attr['lang']
            if len(entities_attr['hashtags']) == 0:
                hashtags = 'None'
            else:
                hashtags_list = []
                for hashtag in entities_attr['hashtags']:
                    hashtags_list.append('#' + hashtag['text'])
                hashtags = " ".join(hashtags_list)
            if len(entities_attr['user_mentions']) == 0:
                user_mentions = 'None'
            else:
                user_mentions_list = []
                for user in entities_attr['user_mentions']:
                    user_mentions_list.append('@' + user['screen_name'])
                user_mentions = " ".join(user_mentions_list)
            retweet_count = str(tweet_attr['retweet_count'])
            favorite_count = str(tweet_attr['favorite_count'])
            device = tweet_attr['source']
            if 'Android' in device:
                device = 'Android'
            elif 'Iphone' in device:
                device = 'Iphone'
            elif 'Web Client' in device:
                device = 'Twitter Web Client'
            elif 'Paper' in device:
                device = 'Paper.ii'
            elif 'Tweet Deck' in device:
                device = 'Tweet Deck'
            else:
                device = 'Other'
            user_id = user_attr['id_str']
            user_name = user_attr['name'].replace(',', ' ')
            screen_name = user_attr['screen_name'].replace(',', ' ')
            joining_data = user_attr['created_at']
            tweet_count = str(user_attr['statuses_count'])
            verified = str(user_attr['verified'])
            followers = str(user_attr['followers_count'])
            following = str(user_attr['friends_count'])
            url = user_attr['url']
            if url is None:
                url = 'None'
            text = tweet_attr['full_text'].replace('\n', ' ').replace(',', ' ').replace(';', ' ')
            group = 'ISIS'
            
            row = date_time + ',' + location + ',' + geo + ',' + tweet_id + ',' + lang + ',' + hashtags \
            + ',' + user_mentions + ',' + retweet_count + ',' + favorite_count \
            + ',' + device + ',' + user_id + ',' + user_name + ',' + screen_name \
            + ',' + joining_data + ',' + tweet_count + ',' + verified + ',' + followers \
            + ',' + following + ',' + url + ',' + text + ',' + group + '\n'
            
            f.write(row)

# %%
len(results)
# Out:
# 157

# %%
results[0]
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Mon Apr 01 10:38:08 +0000 2019',
#  'display_text_range': [0, 140],
#  'entities': {'hashtags': [{'indices': [15, 27], 'text': 'Terroristen'},
#    {'indices': [39, 45], 'text': 'Opfer'},
#    {'indices': [56, 62], 'text': 'Islam'},
#    {'indices': [63, 74], 'text': 'Islamismus'},
#    {'indices': [75, 81], 'text': 'Jihad'},
#    {'indices': [82, 85], 'text': 'IS'},
#    {'indices': [86, 91], 'text': 'ISIS'},
#    {'indices': [92, 100], 'text': 'Jesiden'},
#    {'indices': [101, 108], 'text': 'Eziden'},
#    {'indices': [109, 121], 'text': 'Terrorismus'}],
#   'symbols': [],
#   'urls': [],
#   'user_mentions': [{'id': 82326467,
#     'id_str': '82326467',
#     'indices': [3, 13],
#     'name': 'haOlam',
#     'screen_name': 'haOlam_de'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'full_text': 'RT @haOlam_de: #Terroristen gefördert, #Opfer ignoriert #Islam #Islamismus #Jihad #IS #ISIS #Jesiden #Eziden #Terrorismus https://t.co/KTIS…',
#  'geo': None,
#  'id': 1112665440571015168,
#  'id_str': '1112665440571015168',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'de',
#  'metadata': {'iso_language_code': 'de', 'result_type': 'recent'},
#  'place': None,
#  'retweet_count': 4,
#  'retweeted': False,
#  'retweeted_status': {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Apr 01 08:49:43 +0000 2019',
#   'display_text_range': [0, 130],
#   'entities': {'hashtags': [{'indices': [0, 12], 'text': 'Terroristen'},
#     {'indices': [24, 30], 'text': 'Opfer'},
#     {'indices': [41, 47], 'text': 'Islam'},
#     {'indices': [48, 59], 'text': 'Islamismus'},
#     {'indices': [60, 66], 'text': 'Jihad'},
#     {'indices': [67, 70], 'text': 'IS'},
#     {'indices': [71, 76], 'text': 'ISIS'},
#     {'indices': [77, 85], 'text': 'Jesiden'},
#     {'indices': [86, 93], 'text': 'Eziden'},
#     {'indices': [94, 106], 'text': 'Terrorismus'}],
#    'symbols': [],
#    'urls': [{'display_url': 'haolam.de/artikel/Welt/3…',
#      'expanded_url': 'https://haolam.de/artikel/Welt/37044/Terroristen-gefoerdert-Opfer-ignoriert.html',
#      'indices': [107, 130],
#      'url': 'https://t.co/KTISErN6Lb'}],
#    'user_mentions': []},
#   'favorite_count': 3,
#   'favorited': False,
#   'full_text': '#Terroristen gefördert, #Opfer ignoriert #Islam #Islamismus #Jihad #IS #ISIS #Jesiden #Eziden #Terrorismus https://t.co/KTISErN6Lb',
#   'geo': None,
#   'id': 1112638159941181440,
#   'id_str': '1112638159941181440',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'de',
#   'metadata': {'iso_language_code': 'de', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 4,
#   'retweeted': False,
#   'source': '<a href="http://www.facebook.com/twitter" rel="nofollow">Facebook</a>',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Wed Oct 14 10:17:27 +0000 2009',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'haOlam.de - das deutsch-israelische Onlinemagazin',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'haOlam.de',
#        'expanded_url': 'http://www.haOlam.de',
#        'indices': [0, 22],
#        'url': 'http://t.co/CJyQABGfCl'}]}},
#    'favourites_count': 1,
#    'follow_request_sent': False,
#    'followers_count': 973,
#    'following': False,
#    'friends_count': 192,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 82326467,
#    'id_str': '82326467',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'de',
#    'listed_count': 92,
#    'location': 'Berlin / Jerusalem / Tel Aviv',
#    'name': 'haOlam',
#    'notifications': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme2/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme2/bg.gif',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/82326467/1520804980',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/972953538027577344/98IT85tj_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/972953538027577344/98IT85tj_normal.jpg',
#    'profile_link_color': 'ABB8C2',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'haOlam_de',
#    'statuses_count': 29755,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'http://t.co/CJyQABGfCl',
#    'utc_offset': None,
#    'verified': False}},
#  'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#   'created_at': 'Thu Apr 23 20:09:39 +0000 2015',
#   'default_profile': False,
#   'default_profile_image': False,
#   'description': 'https://t.co/yq4iSI0Hjh / https://t.co/gtJVEssuYr / https://t.co/zeyG5mIXZg / https://t.co/uHkV9V5qSh / https://t.co/Ayj3PEHJa5 / https://t.co/VHp3SjyaK1',
#   'entities': {'description': {'urls': [{'display_url': '0cn.de/Homosexuality1',
#       'expanded_url': 'http://0cn.de/Homosexuality1',
#       'indices': [0, 23],
#       'url': 'https://t.co/yq4iSI0Hjh'},
#      {'display_url': 'ogy.de/RealLove',
#       'expanded_url': 'http://ogy.de/RealLove',
#       'indices': [26, 49],
#       'url': 'https://t.co/gtJVEssuYr'},
#      {'display_url': '0cn.de/YouAre',
#       'expanded_url': 'http://0cn.de/YouAre',
#       'indices': [52, 75],
#       'url': 'https://t.co/zeyG5mIXZg'},
#      {'display_url': '0cn.de/ERlebt',
#       'expanded_url': 'http://0cn.de/ERlebt',
#       'indices': [78, 101],
#       'url': 'https://t.co/uHkV9V5qSh'},
#      {'display_url': '0cn.de/Joh316',
#       'expanded_url': 'http://0cn.de/Joh316',
#       'indices': [104, 127],
#       'url': 'https://t.co/Ayj3PEHJa5'},
#      {'display_url': '0cn.de/darwin2',
#       'expanded_url': 'http://0cn.de/darwin2',
#       'indices': [130, 153],
#       'url': 'https://t.co/VHp3SjyaK1'}]},
#    'url': {'urls': [{'display_url': '0cn.de/GottesHeilsplan',
#       'expanded_url': 'http://0cn.de/GottesHeilsplan',
#       'indices': [0, 23],
#       'url': 'https://t.co/dLKSrXOIQ9'}]}},
#   'favourites_count': 46568,
#   'follow_request_sent': False,
#   'followers_count': 294,
#   'following': False,
#   'friends_count': 1993,
#   'geo_enabled': False,
#   'has_extended_profile': False,
#   'id': 3198947865,
#   'id_str': '3198947865',
#   'is_translation_enabled': False,
#   'is_translator': False,
#   'lang': 'de',
#   'listed_count': 4,
#   'location': 'Phil.3:20 / Germany | ogy.de/Humanism | 0cn.de/Wars1',
#   'name': '„Ki Ko Ahav...“ 👑✝❤🇮🇱',
#   'notifications': False,
#   'profile_background_color': '131516',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3198947865/1491798574',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/998980430454910976/D1BCFar1_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/998980430454910976/D1BCFar1_normal.jpg',
#   'profile_link_color': 'FB881B',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'protected': False,
#   'screen_name': 'KingsSon1987',
#   'statuses_count': 17983,
#   'time_zone': None,
#   'translator_type': 'none',
#   'url': 'https://t.co/dLKSrXOIQ9',
#   'utc_offset': None,
#   'verified': False}}

# %%
x = results[1]['retweeted_status']['entities']['hashtags'][0]['text']
x = '#' + x
x
# Out:
# '#SDF'
