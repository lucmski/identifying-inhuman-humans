# %%
import tweepy
import csv
import pprint
import json

# %%
# sagar's keys
# consumer_key = 'KlIvRIuDPRq6NQTdFPXpVh96v'
# consumer_secret = 'I92dpWQo89ULGCNmpGtwo01t5fVRvWyhPPJyXRTr3cN6KBwtCV'
# access_token = '866792900-KS0Y8s2nl4haGSyGax2E1PPAGoxejfCeSh18weU8'
# access_token_secret = 'SgtPu7DH7mCjbbXVETSSdGt07o8IBdkEJHI55sQKHdavT'

# kshitij's keys
consumer_key = "yyeI5zSWvvLVGSol7hu0tJ9gE"
consumer_secret = "3N4fjsuLTCV4tIXEMICf587lM6mC7i8kcF4Ju1FSnx6VdKKLaW"
access_token = "187109182-3vx120Tp28CEDfKZXB3JaZd5SV04DIZkhuIPEWfG"
access_token_secret = "OXA5aGEXXqibb1FKl31EyVdLVVBqZnDrzS22oLy6KzCuh"

auth = tweepy.auth.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
results_no_retweets = []
try:
    for status in tweepy.Cursor(api.search, q = "#ISIS -filter:retweets", tweet_mode = 'extended').items():
        results_no_retweets.append(status._json)
except :
    print('error')
# Out:
# error

# %%
# results = [status._json for status in tweepy.Cursor(api.search, q="#ISIS", count = 2000, tweet_mode='extended').items()]
# latest  ID (#ISIS)- 1112642900733714432
# latest ID (#AlQaeda) - 1109085045304844290
# latest ID (#alQaida) - 1104080012578304001
results = []
try:
    for status in tweepy.Cursor(api.search, q = "#ISIS", tweet_mode = 'extended', since_id = 1111632240952385536).items():
        results.append(status._json)
except :
    print('error')

# %%
pprint.pprint(results[1]['retweeted_status']['entities']['hashtags'][0]['text'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-390-e1ca89db0010> in <module>()
# ----> 1 pprint.pprint(results[1]['retweeted_status']['entities']['hashtags'][0]['text'])
#
# KeyError: 'retweeted_status'

# %%
results = []
with open('./alqaeda_tweets.json', 'r') as f:
    for item in f:
        results.append(json.loads(item))

# %%
with open('new_isis_tweets.csv', 'a') as f:
    header = 'DateTime,Location,Geo Tag,Tweet ID,Language,Hashtags,User Mentions,Retweet Count,Tweet Favorite Count,Device,User Id,User Name,Screen Name,Active Since,Tweet Count,Verification Status,Followers Count,Following Count,URL,Full Tweet, Terror Group'
    f.write(header)
    f.write('\n')

# %%
with open('new_isis_tweets.csv', 'a') as f:
    for tweet in results:
        if 'retweeted_status' in tweet.keys():
            
            tweet_attr = tweet['retweeted_status']
            user_attr = tweet['retweeted_status']['user']
            entities_attr = tweet['retweeted_status']['entities']
            
            date_time = tweet_attr['created_at']
            location = tweet_attr['user']['location'].replace(',', ' ')
            if len(location) == 0:
                location = 'None'
            geo = tweet_attr['geo']
            if geo is None:
                geo = 'None'
            else:
                geo = str(geo['coordinates'][0]) + str(geo['coordinates'][1])
            tweet_id = tweet_attr['id_str']
            lang = tweet_attr['lang']
            if len(entities_attr['hashtags']) == 0:
                hashtags = 'None'
            else:
                hashtags_list = []
                for hashtag in entities_attr['hashtags']:
                    hashtags_list.append('#' + hashtag['text'])
                hashtags = " ".join(hashtags_list)
            if len(entities_attr['user_mentions']) == 0:
                user_mentions = 'None'
            else:
                user_mentions_list = []
                for user in entities_attr['user_mentions']:
                    user_mentions_list.append('@' + user['screen_name'])
                user_mentions = ' '.join(user_mentions_list)
            retweet_count = str(tweet_attr['retweet_count'])
            favorite_count = str(tweet_attr['favorite_count'])
            device = tweet_attr['source']
            if 'Android' in device:
                device = 'Android'
            elif 'Iphone' in device:
                device = 'Iphone'
            elif 'Web Client' in device:
                device = 'Twitter Web Client'
            elif 'Paper' in device:
                device = 'Paper.ii'
            elif 'Tweet Deck' in device:
                device = 'Tweet Deck'
            else:
                device = 'Other'
            user_id = user_attr['id_str']
            user_name = user_attr['name'].replace(',', ' ')
            screen_name = user_attr['screen_name'].replace(',', ' ')
            joining_data = user_attr['created_at']
            tweet_count = str(user_attr['statuses_count'])
            verified = str(user_attr['verified'])
            followers = str(user_attr['followers_count'])
            following = str(user_attr['friends_count'])
            url = user_attr['url']
            if url is None:
                url = 'None'
            text = tweet_attr['full_text'].replace('\n', ' ').replace(',', ' ').replace(';', ' ')
            group = 'ISIS'
            
            row = date_time + ',' + location + ',' + geo + ',' + tweet_id + ',' + lang + ',' + hashtags \
            + ',' + user_mentions + ',' + retweet_count + ',' + favorite_count \
            + ',' + device + ',' + user_id + ',' + user_name + ',' + screen_name \
            + ',' + joining_data + ',' + tweet_count + ',' + verified + ',' + followers \
            + ',' + following + ',' + url + ',' + text + ',' + group + '\n'
            
            f.write(row)
        
        else:
            
            tweet_attr = tweet
            user_attr = tweet_attr['user']
            entities_attr = tweet['entities']
            
            date_time = tweet_attr['created_at']
            location = tweet_attr['user']['location'].replace(',', ' ')
            if len(location) == 0:
                location = 'None'
            geo = tweet_attr['geo']
            if geo is None:
                geo = 'None'
            else:
                geo = str(geo['coordinates'][0]) + str(geo['coordinates'][1])
            tweet_id = tweet_attr['id_str']
            lang = tweet_attr['lang']
            if len(entities_attr['hashtags']) == 0:
                hashtags = 'None'
            else:
                hashtags_list = []
                for hashtag in entities_attr['hashtags']:
                    hashtags_list.append('#' + hashtag['text'])
                hashtags = " ".join(hashtags_list)
            if len(entities_attr['user_mentions']) == 0:
                user_mentions = 'None'
            else:
                user_mentions_list = []
                for user in entities_attr['user_mentions']:
                    user_mentions_list.append('@' + user['screen_name'])
                user_mentions = " ".join(user_mentions_list)
            retweet_count = str(tweet_attr['retweet_count'])
            favorite_count = str(tweet_attr['favorite_count'])
            device = tweet_attr['source']
            if 'Android' in device:
                device = 'Android'
            elif 'Iphone' in device:
                device = 'Iphone'
            elif 'Web Client' in device:
                device = 'Twitter Web Client'
            elif 'Paper' in device:
                device = 'Paper.ii'
            elif 'Tweet Deck' in device:
                device = 'Tweet Deck'
            else:
                device = 'Other'
            user_id = user_attr['id_str']
            user_name = user_attr['name'].replace(',', ' ')
            screen_name = user_attr['screen_name'].replace(',', ' ')
            joining_data = user_attr['created_at']
            tweet_count = str(user_attr['statuses_count'])
            verified = str(user_attr['verified'])
            followers = str(user_attr['followers_count'])
            following = str(user_attr['friends_count'])
            url = user_attr['url']
            if url is None:
                url = 'None'
            text = tweet_attr['full_text'].replace('\n', ' ').replace(',', ' ').replace(';', ' ')
            group = 'ISIS'
            
            row = date_time + ',' + location + ',' + geo + ',' + tweet_id + ',' + lang + ',' + hashtags \
            + ',' + user_mentions + ',' + retweet_count + ',' + favorite_count \
            + ',' + device + ',' + user_id + ',' + user_name + ',' + screen_name \
            + ',' + joining_data + ',' + tweet_count + ',' + verified + ',' + followers \
            + ',' + following + ',' + url + ',' + text + ',' + group + '\n'
            
            f.write(row)

# %%
len(results)
# Out:
# 692

# %%
results[0]
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Mon Apr 01 09:08:34 +0000 2019',
#  'display_text_range': [0, 144],
#  'entities': {'hashtags': [{'indices': [87, 92], 'text': 'ISIS'}],
#   'symbols': [],
#   'urls': [],
#   'user_mentions': [{'id': 528980698,
#     'id_str': '528980698',
#     'indices': [3, 16],
#     'name': 'Mohammed',
#     'screen_name': 'MazAlJumaily'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'full_text': 'RT @MazAlJumaily: This is a shocking video supposedly showing the passports of foreign #ISIS militants &amp; their families left behind in #Bag…',
#  'geo': None,
#  'id': 1112642900733714432,
#  'id_str': '1112642900733714432',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#  'place': None,
#  'retweet_count': 483,
#  'retweeted': False,
#  'retweeted_status': {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sat Mar 30 11:17:03 +0000 2019',
#   'display_text_range': [0, 232],
#   'entities': {'hashtags': [{'indices': [69, 74], 'text': 'ISIS'},
#     {'indices': [121, 129], 'text': 'Baghouz'}],
#    'media': [{'display_url': 'pic.twitter.com/htOb3BM0hm',
#      'expanded_url': 'https://twitter.com/bave_walat/status/1111550025782439942/video/1',
#      'id': 1111549796593139712,
#      'id_str': '1111549796593139712',
#      'indices': [209, 232],
#      'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1111549796593139712/pu/img/sebLTRTEfjMMM1oq.jpg',
#      'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1111549796593139712/pu/img/sebLTRTEfjMMM1oq.jpg',
#      'sizes': {'large': {'h': 360, 'resize': 'fit', 'w': 640},
#       'medium': {'h': 360, 'resize': 'fit', 'w': 640},
#       'small': {'h': 360, 'resize': 'fit', 'w': 640},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 1111550025782439942,
#      'source_status_id_str': '1111550025782439942',
#      'source_user_id': 858060129224228864,
#      'source_user_id_str': '858060129224228864',
#      'type': 'photo',
#      'url': 'https://t.co/htOb3BM0hm'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 858060129224228864,
#      'id_str': '858060129224228864',
#      'indices': [197, 208],
#      'name': 'BaveWalat',
#      'screen_name': 'bave_walat'}]},
#   'extended_entities': {'media': [{'additional_media_info': {'monetizable': False},
#      'display_url': 'pic.twitter.com/htOb3BM0hm',
#      'expanded_url': 'https://twitter.com/bave_walat/status/1111550025782439942/video/1',
#      'id': 1111549796593139712,
#      'id_str': '1111549796593139712',
#      'indices': [209, 232],
#      'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1111549796593139712/pu/img/sebLTRTEfjMMM1oq.jpg',
#      'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1111549796593139712/pu/img/sebLTRTEfjMMM1oq.jpg',
#      'sizes': {'large': {'h': 360, 'resize': 'fit', 'w': 640},
#       'medium': {'h': 360, 'resize': 'fit', 'w': 640},
#       'small': {'h': 360, 'resize': 'fit', 'w': 640},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 1111550025782439942,
#      'source_status_id_str': '1111550025782439942',
#      'source_user_id': 858060129224228864,
#      'source_user_id_str': '858060129224228864',
#      'type': 'video',
#      'url': 'https://t.co/htOb3BM0hm',
#      'video_info': {'aspect_ratio': [16, 9],
#       'duration_millis': 89600,
#       'variants': [{'bitrate': 256000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/1111549796593139712/pu/vid/320x180/4UXJWHoV4tYYmRrt.mp4?tag=8'},
#        {'bitrate': 832000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/1111549796593139712/pu/vid/640x360/4R5yXELGQ5PIpWEZ.mp4?tag=8'},
#        {'content_type': 'application/x-mpegURL',
#         'url': 'https://video.twimg.com/ext_tw_video/1111549796593139712/pu/pl/HzmdWKU6cq1QAfhl.m3u8?tag=8'}]}}]},
#   'favorite_count': 502,
#   'favorited': False,
#   'full_text': 'This is a shocking video supposedly showing the passports of foreign #ISIS militants &amp; their families left behind in #Baghouz. The reporter says all have Turkish stamps in their passports. Via @bave_walat https://t.co/htOb3BM0hm',
#   'geo': None,
#   'id': 1111950458560675840,
#   'id_str': '1111950458560675840',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 483,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Mar 19 00:51:22 +0000 2012',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'MENA Research Analyst @integrity_UK. Tweet about Iraq, Levant, Gulf, wider MENA region, global affairs and other random stuff.',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 1326,
#    'follow_request_sent': False,
#    'followers_count': 959,
#    'following': False,
#    'friends_count': 415,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 528980698,
#    'id_str': '528980698',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 13,
#    'location': '',
#    'name': 'Mohammed',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/528980698/1546957429',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/761801134445043713/Fxs9mO25_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/761801134445043713/Fxs9mO25_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'MazAlJumaily',
#    'statuses_count': 2785,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#   'created_at': 'Sat Oct 08 10:33:29 +0000 2011',
#   'default_profile': False,
#   'default_profile_image': False,
#   'description': '',
#   'entities': {'description': {'urls': []}},
#   'favourites_count': 40968,
#   'follow_request_sent': False,
#   'followers_count': 1721,
#   'following': False,
#   'friends_count': 2444,
#   'geo_enabled': True,
#   'has_extended_profile': True,
#   'id': 387031748,
#   'id_str': '387031748',
#   'is_translation_enabled': False,
#   'is_translator': False,
#   'lang': 'en',
#   'listed_count': 4,
#   'location': 'Cairo',
#   'name': 'Hossam',
#   'notifications': False,
#   'profile_background_color': 'C4EBC3',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/387031748/1481565939',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1049644362316111874/PGI_GhZO_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1049644362316111874/PGI_GhZO_normal.jpg',
#   'profile_link_color': '3000B3',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'protected': False,
#   'screen_name': 'ghanem_hossam',
#   'statuses_count': 41933,
#   'time_zone': None,
#   'translator_type': 'none',
#   'url': None,
#   'utc_offset': None,
#   'verified': False}}

# %%
x = results[1]['retweeted_status']['entities']['hashtags'][0]['text']
x = '#' + x
x
# Out:
# '#SDF'
